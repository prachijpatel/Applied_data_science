# %%
import pandas as pd
import numpy as np
def answer_two1():
    energy = pd.read_excel('Energy Indicators.xls').drop(['Unnamed: 0','Unnamed: 1'],axis=1)[17:244]
    energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']

#     print(energy.head(230))
    
    energy=energy.replace('...',np.nan)
    energy['Energy Supply']*=1000000
    def remove_digit(data):
            newData = ''.join([i for i in data if not i.isdigit()])
            i = newData.find('(')
            if i>-1: newData = newData[:i]
            return newData.strip()
    energy['Country']=energy['Country'].apply(remove_digit)
    energy['Country']=energy['Country'].replace(['Republic of Korea','United States of America','United Kingdom of Great Britain and Northern Ireland','China, Hong Kong Special Administrative Region','Bolivia (Plurinational State of)','Switzerland17'],['South Korea','United States','United Kingdom','Hong Kong','Bolivia','Switzerland'])
#     energy=energy.set_index("Country")
    GDP=pd.read_csv('world_bank.csv',skiprows=4)
    GDP=GDP.rename(columns={'Country Name':'Country'})
    GDP['Country']=GDP['Country'].replace(["Korea, Rep.","Iran, Islamic Rep.","Hong Kong SAR, China"],["South Korea","Iran","Hong Kong"])
#     GDP=GDP.set_index("Country")
    ScimEn=pd.read_excel('scimagojr-3.xlsx')
#     Sco=pd.read_excel('scimagojr-3.xlsx')
#     ScimEn=ScimEn.set_index("Country")
#     d_in=energy.merge(GDP, how='inner', left_index=True, right_index=True).merge(ScimEn, how='inner', left_index=True, right_index=True)
#     d_out=energy.merge(GDP, how='outer', left_index=True, right_index=True).merge(ScimEn, how='outer', left_index=True, right_index=True)
    
    df=energy.merge(GDP,how='outer',on='Country').merge(ScimEn,how='outer',on='Country')
    df1=energy.merge(GDP,how='inner',on='Country').merge(ScimEn,how='inner',on='Country')
    return df1
answer_two1()
# Out:
#             Country  Energy Supply  Energy Supply per Capita  % Renewable  \
# 0       Afghanistan   3.210000e+08                      10.0    78.669280
# 1           Albania   1.020000e+08                      35.0   100.000000
# 2           Algeria   1.959000e+09                      51.0     0.551010
# 3    American Samoa            NaN                       NaN     0.641026
# 4           Andorra   9.000000e+06                     121.0    88.695650
# ..              ...            ...                       ...          ...
# 157   United States   9.083800e+10                     286.0    11.570980
# 158         Uruguay   1.960000e+08                      58.0    71.605040
# 159      Uzbekistan   1.798000e+09                      62.0    21.328410
# 160          Zambia   4.000000e+08                      26.0    99.714670
# 161        Zimbabwe   4.800000e+08                      32.0    52.536120
#
#     Country Code                            Indicator Name  Indicator Code  \
# 0            AFG  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 1            ALB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 2            DZA  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 3            ASM  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 4            AND  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# ..           ...                                       ...             ...
# 157          USA  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 158          URY  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 159          UZB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 160          ZMB  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# 161          ZWE  GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
#
#              1960          1961          1962  ...          2013  \
# 0             NaN           NaN           NaN  ...  1.973134e+10
# 1             NaN           NaN           NaN  ...  1.254247e+10
# 2    2.744286e+10  2.370914e+10  1.904199e+10  ...  1.763249e+11
# 3             NaN           NaN           NaN  ...           NaN
# 4             NaN           NaN           NaN  ...  3.127550e+09
# ..            ...           ...           ...  ...           ...
# 157  3.078071e+12  3.148867e+12  3.340948e+12  ...  1.577367e+13
# 158  1.389822e+10  1.424471e+10  1.402042e+10  ...  4.589732e+10
# 159           NaN           NaN           NaN  ...  4.977761e+10
# 160  4.592975e+09  4.655503e+09  4.539542e+09  ...  2.420595e+10
# 161  3.338344e+09  3.549199e+09  3.600111e+09  ...  1.218064e+10
#
#              2014          2015  Rank  Documents  Citable documents  \
# 0    1.999032e+10  2.029415e+10   163          3                  3
# 1    1.279331e+10  1.312082e+10   118         23                 23
# 2    1.830252e+11  1.901632e+11    42       1215               1197
# 3             NaN           NaN   180          1                  1
# 4             NaN           NaN   168          2                  2
# ..            ...           ...   ...        ...                ...
# 157  1.615662e+13  1.654857e+13     2      96661              94747
# 158  4.738384e+10  4.784927e+10    91         71                 70
# 159  5.380959e+10  5.811436e+10    96         57                 56
# 160  2.542227e+10  2.624127e+10   123         19                 19
# 161  1.264939e+10  1.278517e+10   119         22                 21
#
#      Citations  Self-citations  Citations per document  H index
# 0            0               0                    0.00        0
# 1          168              14                    7.30        6
# 2         7393            1413                    6.08       40
# 3            0               0                    0.00        0
# 4           13               0                    6.50        1
# ..         ...             ...                     ...      ...
# 157     792274          265436                    8.20      230
# 158        728              80                   10.25       15
# 159        158              45                    2.77        7
# 160         14               1                    0.74        2
# 161         27               1                    1.23        3
#
# [162 rows x 70 columns]

# %%
def answer_two():
    GDP=pd.read_csv("world_bank.csv",skiprows=4)
    
#     GDP=GDP[["Country Name","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]]
    GDP=pd.read_csv("world_bank.csv",skiprows=4)
    
#     GDP=GDP[["Country Name","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015"]]
    GDP=GDP.replace({"Korea, Rep.": "South Korea", 
        "Iran, Islamic Rep.": "Iran",
        "Hong Kong SAR, China": "Hong Kong"})
    GDP=GDP.set_index("Country Name")
    # ---------------------------------------------------
    ENERGY=pd.read_excel("Energy Indicators.xls",skiprows=16,na_values=["..."])
    ENERGY=ENERGY.drop(["Unnamed: 0","Unnamed: 1"],axis=1)
    ENERGY=ENERGY.drop(ENERGY.index[0],axis=0)
    
    ENERGY=ENERGY.drop(ENERGY.index[227:])

    ENERGY=ENERGY.rename(columns={"Unnamed: 2":"Country","Energy Supply per capita":"Energy Supply per Capita","Renewable Electricity Production":"% Renewable"})
    
    ENERGY["Energy Supply"]=ENERGY["Energy Supply"]*1000000
    f="("
    for i in ENERGY["Country"]:
    #         print(i,s)
    

        contains_digit = any(map(str.isdigit, i))

        if contains_digit:
            numbers = sum(c.isdigit() for c in i)

            ENERGY=ENERGY.replace({i:i[:len(i)-numbers]})
    #         print("if",ENERGY.index[i])
    #         print("-----------------")
    #         elif f[1] in list(s):
    #             ENERGY=ENERGY.rename({ENERGY.index[i]:ENERGY.index[i].split(",")[0].strip()})
    #     #         print("elif1",ENERGY.index[i].split(",")[0].strip())
    #     #         print("-----------------")



        elif f in list(i):
            ENERGY=ENERGY.replace({i:i.split("(")[0].strip()})
    #         print("elif2",ENERGY.index[i])
    #         print("-----------------")
#     print(ENERGY.loc["United Kingdom"])

    def remove_digit(data):
        newData = ''.join([i for i in data if not i.isdigit()])
        i = newData.find('(')
        if i>-1: newData = newData[:i]
        return newData.strip()
    ENERGY=ENERGY.replace({"Republic of Korea": "South Korea","United States of America": "United States",
    "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
    "China, Hong Kong Special Administrative Region": "Hong Kong"})
    ENERGY=ENERGY.set_index("Country")
    # ---------------------------------------------------
    ScimEn=pd.read_excel("scimagojr-3.xlsx")
    #     ScimEn=ScimEn.iloc[:15,:]
    
    ScimEn=ScimEn.set_index("Country")
#     d=pd.merge(ScimEn, ENERGY, how='left', left_index=True, right_index=True)
#     #     print(d.head(30))
#     d=pd.merge( d,GDP, how='left', left_index=True, right_index=True)
#     d=d.sort_values(by=["Rank"])
#     new_d=d.nsmallest(15,"Rank")
#     new_d["% Renewable"]=new_d["% Renewable"].fillna(np.nan)
#     new_d["Energy Supply"]=new_d["Energy Supply"].fillna(np.nan)
#     new_d["Energy Supply per Capita"]=new_d["Energy Supply per Capita"].fillna(np.nan)

    
    #     d.head(30)
#     print(len(ENERGY)-len(d),len(ScimEn)-len(d))
    
#     print(len(GDP),len(ENERGY),len(ScimEn))

#     d=d.sort_values(by=["Rank"])
#     new_d=d.nsmallest(15,"Rank")
#     df=energy.merge(GDP,how='inner',on='Country').merge(ScimEn,how='inner',on='Country')

    d_in=ENERGY.merge(GDP, how='inner', left_index=True, right_index=True).merge(ScimEn, how='inner', left_index=True, right_index=True)
    #     print(d.head(30))
#     d=pd.merge( d,GDP, how='left', left_index=True, right_index=True)
    d_out=ENERGY.merge(GDP, how='outer', left_index=True, right_index=True).merge(ScimEn, how='outer', left_index=True, right_index=True)

#     do=pd.merge(ScimEn, ENERGY, how='outer', left_index=True, right_index=True)
#     do=pd.merge(do, GDP, how='outer', left_index=True, right_index=True)
#     d_out=len(do)
#     print(len(GDP),len(ENERGY),len(ScimEn))
    return d_in
answer_two()
# GDP.shape[0]+ENERGY.shape[0]+ScimEn.shape[0]-3*d.shape[0]
# print(GDP.shape,ENERGY.shape,ScimEn.shape)



# def answer_two1():
#     energy = pd.read_excel('Energy Indicators.xls').drop(['Unnamed: 0','Unnamed: 1'],axis=1)[16:]
#     energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
#     energy=energy.drop(energy.index[0],axis=0)
#     energy=energy.drop(energy.index[227:])
    
#     print(energy.head(230))
    
#     energy.replace('...',np.nan,inplace=True)
#     energy['Energy Supply']*=1000000
#     def remove_digit(data):
#             newData = ''.join([i for i in data if not i.isdigit()])
#             i = newData.find('(')
#             if i>-1: newData = newData[:i]
#             return newData.strip()
#     energy['Country']=energy['Country'].apply(remove_digit)
#     energy['Country']=energy['Country'].replace(['Republic of Korea','United States of America','United Kingdom of Great Britain and Northern Ireland','China, Hong Kong Special Administrative Region','Bolivia (Plurinational State of)','Switzerland17'],['South Korea','United States','United Kingdom','Hong Kong','Bolivia','Switzerland'])

#     GDP=pd.read_csv('world_bank.csv',skiprows=4)
#     GDP.rename(columns={'Country Name':'Country'},inplace=True)
#     GDP['Country']=GDP['Country'].replace(["Korea, Rep.","Iran, Islamic Rep.","Hong Kong SAR, China"],["South Korea","Iran","Hong Kong"])

#     ScimEn=pd.read_excel('scimagojr-3.xlsx')
# #     Sco=pd.read_excel('scimagojr-3.xlsx')

#     df=energy.merge(GDP,how='outer',on='Country').merge(ScimEn,how='outer',on='Country')
#     df1=energy.merge(GDP,how='inner',on='Country').merge(ScimEn,how='inner',on='Country')
#     return df.shape[0]-df1.shape[0]
# answer_two1()





































# print(answer_two1()==answer_two())
# Out:
#                 Energy Supply  Energy Supply per Capita  % Renewable  \
# Afghanistan      3.210000e+08                      10.0    78.669280
# Albania          1.020000e+08                      35.0   100.000000
# Algeria          1.959000e+09                      51.0     0.551010
# American Samoa            NaN                       NaN     0.641026
# Andorra          9.000000e+06                     121.0    88.695650
# ...                       ...                       ...          ...
# Uruguay          1.960000e+08                      58.0    71.605040
# Uzbekistan       1.798000e+09                      62.0    21.328410
# Vanuatu          3.000000e+06                      10.0    14.705880
# Zambia           4.000000e+08                      26.0    99.714670
# Zimbabwe         4.800000e+08                      32.0    52.536120
#
#                Country Code                            Indicator Name  \
# Afghanistan             AFG  GDP at market prices (constant 2010 US$)
# Albania                 ALB  GDP at market prices (constant 2010 US$)
# Algeria                 DZA  GDP at market prices (constant 2010 US$)
# American Samoa          ASM  GDP at market prices (constant 2010 US$)
# Andorra                 AND  GDP at market prices (constant 2010 US$)
# ...                     ...                                       ...
# Uruguay                 URY  GDP at market prices (constant 2010 US$)
# Uzbekistan              UZB  GDP at market prices (constant 2010 US$)
# Vanuatu                 VUT  GDP at market prices (constant 2010 US$)
# Zambia                  ZMB  GDP at market prices (constant 2010 US$)
# Zimbabwe                ZWE  GDP at market prices (constant 2010 US$)
#
#                 Indicator Code          1960          1961          1962  \
# Afghanistan     NY.GDP.MKTP.KD           NaN           NaN           NaN
# Albania         NY.GDP.MKTP.KD           NaN           NaN           NaN
# Algeria         NY.GDP.MKTP.KD  2.744286e+10  2.370914e+10  1.904199e+10
# American Samoa  NY.GDP.MKTP.KD           NaN           NaN           NaN
# Andorra         NY.GDP.MKTP.KD           NaN           NaN           NaN
# ...                        ...           ...           ...           ...
# Uruguay         NY.GDP.MKTP.KD  1.389822e+10  1.424471e+10  1.402042e+10
# Uzbekistan      NY.GDP.MKTP.KD           NaN           NaN           NaN
# Vanuatu         NY.GDP.MKTP.KD           NaN           NaN           NaN
# Zambia          NY.GDP.MKTP.KD  4.592975e+09  4.655503e+09  4.539542e+09
# Zimbabwe        NY.GDP.MKTP.KD  3.338344e+09  3.549199e+09  3.600111e+09
#
#                         1963  ...          2006          2007          2008  \
# Afghanistan              NaN  ...  1.030523e+10  1.172119e+10  1.214448e+10
# Albania                  NaN  ...  9.771760e+09  1.034829e+10  1.112752e+10
# Algeria         2.557600e+10  ...  1.446474e+11  1.495654e+11  1.531550e+11
# American Samoa           NaN  ...           NaN           NaN           NaN
# Andorra                  NaN  ...  4.018196e+09  4.021331e+09  3.675728e+09
# ...                      ...  ...           ...           ...           ...
# Uruguay         1.404432e+10  ...  3.139363e+10  3.344725e+10  3.584747e+10
# Uzbekistan               NaN  ...  2.798925e+10  3.076611e+10  3.353506e+10
# Vanuatu                  NaN  ...  5.961693e+08  6.270251e+08  6.674589e+08
# Zambia          4.688093e+09  ...  1.440569e+10  1.560892e+10  1.682234e+10
# Zimbabwe        3.824915e+09  ...  1.006276e+10  9.695130e+09  7.982103e+09
#
#                         2009          2010          2011          2012  \
# Afghanistan     1.469733e+10  1.593680e+10  1.691113e+10  1.935220e+10
# Albania         1.150029e+10  1.192695e+10  1.223109e+10  1.240477e+10
# Algeria         1.556055e+11  1.612073e+11  1.658823e+11  1.715223e+11
# American Samoa           NaN           NaN           NaN           NaN
# Andorra         3.535389e+09  3.346317e+09  3.185605e+09  3.129538e+09
# ...                      ...           ...           ...           ...
# Uruguay         3.736865e+10  4.028468e+10  4.236423e+10  4.386315e+10
# Uzbekistan      3.625140e+10  3.933277e+10  4.259739e+10  4.609038e+10
# Vanuatu         6.895706e+08  7.008043e+08  7.093767e+08  7.218245e+08
# Zambia          1.837342e+10  2.026555e+10  2.140358e+10  2.302438e+10
# Zimbabwe        8.459783e+09  9.422161e+09  1.054391e+10  1.165789e+10
#
#                         2013          2014          2015
# Afghanistan     1.973134e+10  1.999032e+10  2.029415e+10
# Albania         1.254247e+10  1.279331e+10  1.312082e+10
# Algeria         1.763249e+11  1.830252e+11  1.901632e+11
# American Samoa           NaN           NaN           NaN
# Andorra         3.127550e+09           NaN           NaN
# ...                      ...           ...           ...
# Uruguay         4.589732e+10  4.738384e+10  4.784927e+10
# Uzbekistan      4.977761e+10  5.380959e+10  5.811436e+10
# Vanuatu         7.360383e+08  7.529991e+08           NaN
# Zambia          2.420595e+10  2.542227e+10  2.624127e+10
# Zimbabwe        1.218064e+10  1.264939e+10  1.278517e+10
#
# [186 rows x 62 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2d11469496c8> in <module>
# ----> 1 d_out
#
# NameError: name 'd_out' is not defined
